# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)

# %% [markdown]
# # Goal
# The August 2022 edition of the Tabular Playground Series is an opportunity to help the fictional company Keep It Dry improve its main product Super Soaker. The product is used in factories to absorb spills and leaks.
#
# The company has just completed a large testing study for different product prototypes. Can you use this data to build a model that predicts product failures?

# %%
train = pd.read_csv('../input/tabular-playground-series-aug-2022/train.csv')
test = pd.read_csv('../input/tabular-playground-series-aug-2022/test.csv')
sub = pd.read_csv('../input/tabular-playground-series-aug-2022/sample_submission.csv')

print(train.shape)
print(test.shape)
print(sub.shape)
# Out:
# (26570, 26)
# (20775, 25)
# (20775, 2)

# %%
train
# Out:
#           id product_code  loading attribute_0 attribute_1  attribute_2  \
# 0          0            A    80.10  material_7  material_8            9
# 1          1            A    84.89  material_7  material_8            9
# 2          2            A    82.43  material_7  material_8            9
# 3          3            A   101.07  material_7  material_8            9
# 4          4            A   188.06  material_7  material_8            9
# ...      ...          ...      ...         ...         ...          ...
# 26565  26565            E   158.95  material_7  material_6            6
# 26566  26566            E   146.02  material_7  material_6            6
# 26567  26567            E   115.62  material_7  material_6            6
# 26568  26568            E   106.38  material_7  material_6            6
# 26569  26569            E   131.20  material_7  material_6            6
#
#        attribute_3  measurement_0  measurement_1  measurement_2  \
# 0                5              7              8              4
# 1                5             14              3              3
# 2                5             12              1              5
# 3                5             13              2              6
# 4                5              9              2              8
# ...            ...            ...            ...            ...
# 26565            9              6             16              4
# 26566            9             10             12              8
# 26567            9              1             10              1
# 26568            9              2              9              4
# 26569            9              6             19              1
#
#        measurement_3  measurement_4  measurement_5  measurement_6  \
# 0             18.040         12.518         15.748         19.292
# 1             18.213         11.540         17.717         17.893
# 2             18.057         11.652         16.738         18.240
# 3             17.295         11.188         18.576         18.339
# 4             19.346         12.950         16.990         15.746
# ...              ...            ...            ...            ...
# 26565         16.301         13.259         18.068         15.505
# 26566         17.543            NaN         17.984         19.078
# 26567         15.670         11.535         16.778         18.385
# 26568         18.059            NaN         16.918         18.101
# 26569         18.034         11.431         16.918         17.129
#
#        measurement_7  measurement_8  measurement_9  measurement_10  \
# 0             11.739         20.155         10.672          15.859
# 1             12.748         17.889         12.448          17.947
# 2             12.718         18.288         12.715          15.607
# 3             12.583         19.060         12.471          16.346
# 4             11.306         18.093         10.337          17.082
# ...              ...            ...            ...             ...
# 26565         10.865         19.354            NaN          12.177
# 26566         11.139         19.563         11.242          14.179
# 26567         11.630         19.279         11.407          16.437
# 26568         11.713         19.358         11.392          17.064
# 26569         12.713         18.731         10.611          15.603
#
#        measurement_11  measurement_12  measurement_13  measurement_14  \
# 0              17.594          15.193          15.029             NaN
# 1              17.915          11.755          14.732          15.425
# 2                 NaN          13.798          16.711          18.631
# 3              18.377          10.020          15.250          15.562
# 4              19.932          12.428          16.182          12.760
# ...               ...             ...             ...             ...
# 26565          17.942          10.112          15.795          18.572
# 26566          20.564          10.234          14.450          14.322
# 26567          17.476           8.668          15.069          16.599
# 26568          17.814          14.928          16.273          15.485
# 26569          19.703          11.006          15.875          13.366
#
#        measurement_15  measurement_16  measurement_17  failure
# 0              13.034          14.684         764.100        0
# 1              14.395          15.631         682.057        0
# 2              14.094          17.946         663.376        0
# 3              16.154          17.172         826.282        0
# 4              13.153          16.412         579.885        0
# ...               ...             ...             ...      ...
# 26565          16.144             NaN         729.131        0
# 26566          13.146          16.471         853.924        0
# 26567          15.590          14.065         750.364        0
# 26568          13.624          12.865         730.156        0
# 26569          16.527          17.890         602.354        0
#
# [26570 rows x 26 columns]

# %% [markdown]
# # EDA

# %%
train.duplicated().sum()
# Out:
# 0

# %%
def eda(df):
    summary = pd.DataFrame(df.dtypes, columns = ['dtype'])
    summary['missing'] = df.isnull().sum()
    summary['miss_pct'] = summary['missing']/len(df)
    summary['nlevel'] = df.nunique()
    return summary

eda(train)
# Out:
#                   dtype  missing  miss_pct  nlevel
# id                int64        0  0.000000   26570
# product_code     object        0  0.000000       5
# loading         float64      250  0.009409   11950
# attribute_0      object        0  0.000000       2
# attribute_1      object        0  0.000000       3
# attribute_2       int64        0  0.000000       4
# attribute_3       int64        0  0.000000       4
# measurement_0     int64        0  0.000000      29
# measurement_1     int64        0  0.000000      30
# measurement_2     int64        0  0.000000      25
# measurement_3   float64      381  0.014339    4721
# measurement_4   float64      538  0.020248    4692
# measurement_5   float64      676  0.025442    4671
# measurement_6   float64      796  0.029959    4704
# measurement_7   float64      937  0.035265    4734
# measurement_8   float64     1048  0.039443    4713
# measurement_9   float64     1227  0.046180    4708
# measurement_10  float64     1300  0.048927    6177
# measurement_11  float64     1468  0.055250    6526
# measurement_12  float64     1601  0.060256    6392
# measurement_13  float64     1774  0.066767    5271
# measurement_14  float64     1874  0.070531    6389
# measurement_15  float64     2009  0.075612    6577
# measurement_16  float64     2110  0.079413    7035
# measurement_17  float64     2284  0.085962   23612
# failure           int64        0  0.000000       2

# %%
eda(test)
# Out:
#                   dtype  missing  miss_pct  nlevel
# id                int64        0  0.000000   20775
# product_code     object        0  0.000000       4
# loading         float64      223  0.010734   10741
# attribute_0      object        0  0.000000       2
# attribute_1      object        0  0.000000       3
# attribute_2       int64        0  0.000000       3
# attribute_3       int64        0  0.000000       4
# measurement_0     int64        0  0.000000      30
# measurement_1     int64        0  0.000000      33
# measurement_2     int64        0  0.000000      28
# measurement_3   float64      329  0.015836    4487
# measurement_4   float64      409  0.019687    4514
# measurement_5   float64      508  0.024452    4500
# measurement_6   float64      624  0.030036    4476
# measurement_7   float64      720  0.034657    4493
# measurement_8   float64      846  0.040722    4513
# measurement_9   float64      904  0.043514    4471
# measurement_10  float64     1067  0.051360    6217
# measurement_11  float64     1136  0.054681    6252
# measurement_12  float64     1240  0.059687    5623
# measurement_13  float64     1303  0.062720    5644
# measurement_14  float64     1440  0.069314    5795
# measurement_15  float64     1542  0.074224    6156
# measurement_16  float64     1678  0.080770    6396
# measurement_17  float64     1740  0.083755   18657

# %%
train.failure.value_counts()
# Out:
# 0    20921
# 1     5649
# Name: failure, dtype: int64

# %%
train[['product_code','attribute_0','attribute_1','attribute_2','attribute_3','failure']].value_counts()
# Out:
# product_code  attribute_0  attribute_1  attribute_2  attribute_3  failure
# C             material_7   material_8   5            8            0          4545
# E             material_7   material_6   6            9            0          4237
# B             material_5   material_5   8            8            0          4198
# D             material_7   material_5   6            6            0          4000
# A             material_7   material_8   9            5            0          3941
# C             material_7   material_8   5            8            1          1220
# A             material_7   material_8   9            5            1          1159
# D             material_7   material_5   6            6            1          1112
# E             material_7   material_6   6            9            1          1106
# B             material_5   material_5   8            8            1          1052
# dtype: int64

# %%
test[['product_code','attribute_0','attribute_1','attribute_2','attribute_3']].value_counts()
# Out:
# product_code  attribute_0  attribute_1  attribute_2  attribute_3
# F             material_5   material_6   6            4              5422
# I             material_7   material_5   9            5              5228
# G             material_5   material_6   9            7              5107
# H             material_7   material_7   7            9              5018
# dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.heatmap(train.corr(), cmap = 'coolwarm')
# Out:
# <AxesSubplot:>

# %%
train.corr()['failure'].abs().reset_index().sort_values(by = 'failure',ascending = False)
# Out:
#              index   failure
# 22         failure  1.000000
# 1          loading  0.129089
# 21  measurement_17  0.033905
# 3      attribute_3  0.019222
# 9    measurement_5  0.018079
# 12   measurement_8  0.017119
# 11   measurement_7  0.016787
# 6    measurement_2  0.015808
# 10   measurement_6  0.014791
# 5    measurement_1  0.010810
# 8    measurement_4  0.010488
# 4    measurement_0  0.009646
# 0               id  0.007545
# 2      attribute_2  0.006337
# 18  measurement_14  0.006211
# 15  measurement_11  0.004801
# 16  measurement_12  0.004398
# 13   measurement_9  0.003587
# 7    measurement_3  0.003577
# 19  measurement_15  0.003544
# 20  measurement_16  0.002237
# 17  measurement_13  0.001831
# 14  measurement_10  0.001515

# %%
df = pd.concat([train, test])
print(df.shape)
df.head(3)
# Out:
# (47345, 26)
#    id product_code  loading attribute_0 attribute_1  attribute_2  attribute_3  \
# 0   0            A    80.10  material_7  material_8            9            5
# 1   1            A    84.89  material_7  material_8            9            5
# 2   2            A    82.43  material_7  material_8            9            5
#
#    measurement_0  measurement_1  measurement_2  measurement_3  measurement_4  \
# 0              7              8              4         18.040         12.518
# 1             14              3              3         18.213         11.540
# 2             12              1              5         18.057         11.652
#
#    measurement_5  measurement_6  measurement_7  measurement_8  measurement_9  \
# 0         15.748         19.292         11.739         20.155         10.672
# 1         17.717         17.893         12.748         17.889         12.448
# 2         16.738         18.240         12.718         18.288         12.715
#
#    measurement_10  measurement_11  measurement_12  measurement_13  \
# 0          15.859          17.594          15.193          15.029
# 1          17.947          17.915          11.755          14.732
# 2          15.607             NaN          13.798          16.711
#
#    measurement_14  measurement_15  measurement_16  measurement_17  failure
# 0             NaN          13.034          14.684         764.100      0.0
# 1          15.425          14.395          15.631         682.057      0.0
# 2          18.631          14.094          17.946         663.376      0.0

# %% [markdown]
# # FE

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
for c in ['product_code','attribute_0','attribute_1']:
    df[c] = le.fit_transform(df[c])
    
df.head(2)
# Out:
#    id  product_code  loading  attribute_0  attribute_1  attribute_2  \
# 0   0             0    80.10            1            3            9
# 1   1             0    84.89            1            3            9
#
#    attribute_3  measurement_0  measurement_1  measurement_2  measurement_3  \
# 0            5              7              8              4         18.040
# 1            5             14              3              3         18.213
#
#    measurement_4  measurement_5  measurement_6  measurement_7  measurement_8  \
# 0         12.518         15.748         19.292         11.739         20.155
# 1         11.540         17.717         17.893         12.748         17.889
#
#    measurement_9  measurement_10  measurement_11  measurement_12  \
# 0         10.672          15.859          17.594          15.193
# 1         12.448          17.947          17.915          11.755
#
#    measurement_13  measurement_14  measurement_15  measurement_16  \
# 0          15.029             NaN          13.034          14.684
# 1          14.732          15.425          14.395          15.631
#
#    measurement_17  failure
# 0         764.100      0.0
# 1         682.057      0.0

# %%
######################### Freq encoding

for col in ['attribute_0','attribute_1','attribute_2','attribute_3']:    
    fq_encode = df[col].value_counts(dropna= True, normalize = True).to_dict()   
    df[col+'_fq_enc'] = df[col].map(fq_encode)

    
############################ Agg features   
main_cols = ['loading','measurement_11']
ag_cols = ['attribute_0','attribute_1','attribute_2','attribute_3']

for col_a in main_cols: 
    for col_b in ag_cols:
        df[col_a + '_' + col_b + '_mean'] = df.groupby(col_b)[col_a].transform('mean')    
        df[col_a + '_' + col_b + '_std'] = df.groupby(col_b)[col_a].transform('std')
        #df[col_a + '_' + col_b + '_median'] = df.groupby(col_b)[col_a].transform('median')

df['loading+measurement9'] = df['loading'] + df['measurement_9']        
df['loading+measurement11'] = df['loading'] + df['measurement_11'] 
df['measurement_11+9'] = df['measurement_11'] + df['measurement_9'] 

df.head()
# Out:
#    id  product_code  loading  attribute_0  attribute_1  attribute_2  \
# 0   0             0    80.10            1            3            9
# 1   1             0    84.89            1            3            9
# 2   2             0    82.43            1            3            9
# 3   3             0   101.07            1            3            9
# 4   4             0   188.06            1            3            9
#
#    attribute_3  measurement_0  measurement_1  measurement_2  measurement_3  \
# 0            5              7              8              4         18.040
# 1            5             14              3              3         18.213
# 2            5             12              1              5         18.057
# 3            5             13              2              6         17.295
# 4            5              9              2              8         19.346
#
#    measurement_4  measurement_5  measurement_6  measurement_7  measurement_8  \
# 0         12.518         15.748         19.292         11.739         20.155
# 1         11.540         17.717         17.893         12.748         17.889
# 2         11.652         16.738         18.240         12.718         18.288
# 3         11.188         18.576         18.339         12.583         19.060
# 4         12.950         16.990         15.746         11.306         18.093
#
#    measurement_9  measurement_10  measurement_11  measurement_12  \
# 0         10.672          15.859          17.594          15.193
# 1         12.448          17.947          17.915          11.755
# 2         12.715          15.607             NaN          13.798
# 3         12.471          16.346          18.377          10.020
# 4         10.337          17.082          19.932          12.428
#
#    measurement_13  measurement_14  measurement_15  measurement_16  \
# 0          15.029             NaN          13.034          14.684
# 1          14.732          15.425          14.395          15.631
# 2          16.711          18.631          14.094          17.946
# 3          15.250          15.562          16.154          17.172
# 4          16.182          12.760          13.153          16.412
#
#    measurement_17  failure  attribute_0_fq_enc  attribute_1_fq_enc  \
# 0         764.100      0.0            0.666723            0.229486
# 1         682.057      0.0            0.666723            0.229486
# 2         663.376      0.0            0.666723            0.229486
# 3         826.282      0.0            0.666723            0.229486
# 4         579.885      0.0            0.666723            0.229486
#
#    attribute_2_fq_enc  attribute_3_fq_enc  loading_attribute_0_mean  \
# 0            0.326011            0.218143                127.856901
# 1            0.326011            0.218143                127.856901
# 2            0.326011            0.218143                127.856901
# 3            0.326011            0.218143                127.856901
# 4            0.326011            0.218143                127.856901
#
#    loading_attribute_0_std  loading_attribute_1_mean  loading_attribute_1_std  \
# 0                39.257627                127.818301                39.369755
# 1                39.257627                127.818301                39.369755
# 2                39.257627                127.818301                39.369755
# 3                39.257627                127.818301                39.369755
# 4                39.257627                127.818301                39.369755
#
#    loading_attribute_2_mean  loading_attribute_2_std  \
# 0                127.970287                39.288624
# 1                127.970287                39.288624
# 2                127.970287                39.288624
# 3                127.970287                39.288624
# 4                127.970287                39.288624
#
#    loading_attribute_3_mean  loading_attribute_3_std  \
# 0                127.836972                39.155805
# 1                127.836972                39.155805
# 2                127.836972                39.155805
# 3                127.836972                39.155805
# 4                127.836972                39.155805
#
#    measurement_11_attribute_0_mean  measurement_11_attribute_0_std  \
# 0                         19.16119                         1.50365
# 1                         19.16119                         1.50365
# 2                         19.16119                         1.50365
# 3                         19.16119                         1.50365
# 4                         19.16119                         1.50365
#
#    measurement_11_attribute_1_mean  measurement_11_attribute_1_std  \
# 0                        19.091088                         1.60499
# 1                        19.091088                         1.60499
# 2                        19.091088                         1.60499
# 3                        19.091088                         1.60499
# 4                        19.091088                         1.60499
#
#    measurement_11_attribute_2_mean  measurement_11_attribute_2_std  \
# 0                        19.222873                        1.674223
# 1                        19.222873                        1.674223
# 2                        19.222873                        1.674223
# 3                        19.222873                        1.674223
# 4                        19.222873                        1.674223
#
#    measurement_11_attribute_3_mean  measurement_11_attribute_3_std  \
# 0                        19.272901                         1.62291
# 1                        19.272901                         1.62291
# 2                        19.272901                         1.62291
# 3                        19.272901                         1.62291
# 4                        19.272901                         1.62291
#
#    loading+measurement9  loading+measurement11  measurement_11+9
# 0                90.772                 97.694            28.266
# 1                97.338                102.805            30.363
# 2                95.145                    NaN               NaN
# 3               113.541                119.447            30.848
# 4               198.397                207.992            30.269

# %%
train = df[:len(train)]
test = df[-len(test):]

X_train = train.drop(['id','failure'], axis = 1)
X_test = test.drop(['id','failure'], axis = 1)

print(X_train.shape)
print(X_test.shape)

y_train = train.failure

print(y_train.shape)
# Out:
# (26570, 47)
# (20775, 47)
# (26570,)

# %% [markdown]
# # LGBM

# %%
import lightgbm as lgb
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold, StratifiedKFold, GroupKFold

skf = StratifiedKFold(n_splits = 5, shuffle = True, random_state = 2022)
gkf = GroupKFold(n_splits = 5)
preds = np.zeros(len(sub))
oof = np.zeros(len(X_train))

for i, (idxt, idxv) in enumerate(skf.split(X_train, y_train)):
#for i, (idxt, idxv) in enumerate(gkf.split(X_train, groups = grp)):
    
    print('Fold', i+1)
    print('*' * 50)
    
    X_trn, X_val = X_train.iloc[idxt], X_train.iloc[idxv]
    y_trn, y_val = y_train.iloc[idxt], y_train.iloc[idxv]

    clf = lgb.LGBMClassifier(

        n_estimators = 2000,
        learning_rate = 0.03,
        subsample = 0.8,
        colsample_bytree = 0.8,
        reg_alpha = 0.5,
         importance_type = 'gain',
        )
    
    clf.fit(X_trn, y_trn, eval_set = [(X_trn, y_trn), (X_val, y_val)], eval_metric = ['auc'], verbose = 100,
           early_stopping_rounds=200)

    oof[idxv] = clf.predict_proba(X_val)[:,1]
    preds += clf.predict_proba(X_test)[:,1]/skf.n_splits
    
print('OOF ROC', roc_auc_score(y_train, oof))
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>
# Fold 1
# **************************************************
# [100]	training's auc: 0.757404	training's binary_logloss: 0.472465	valid_1's auc: 0.580328	valid_1's binary_logloss: 0.510537
# [200]	training's auc: 0.852335	training's binary_logloss: 0.443631	valid_1's auc: 0.576406	valid_1's binary_logloss: 0.511893
# Fold 2
# **************************************************
# [100]	training's auc: 0.761529	training's binary_logloss: 0.472269	valid_1's auc: 0.582067	valid_1's binary_logloss: 0.510557
# [200]	training's auc: 0.842986	training's binary_logloss: 0.445352	valid_1's auc: 0.5753	valid_1's binary_logloss: 0.512336
# Fold 3
# **************************************************
# [100]	training's auc: 0.752543	training's binary_logloss: 0.473431	valid_1's auc: 0.582088	valid_1's binary_logloss: 0.510331
# [200]	training's auc: 0.844408	training's binary_logloss: 0.445541	valid_1's auc: 0.573603	valid_1's binary_logloss: 0.512007
# Fold 4
# **************************************************
# [100]	training's auc: 0.755826	training's binary_logloss: 0.472077	valid_1's auc: 0.570821	valid_1's binary_logloss: 0.512263
# [200]	training's auc: 0.840951	training's binary_logloss: 0.443814	valid_1's auc: 0.567435	valid_1's binary_logloss: 0.513822
# Fold 5
# **************************************************
# [100]	training's auc: 0.761895	training's binary_logloss: 0.473036	valid_1's auc: 0.585016	valid_1's binary_logloss: 0.509272
# [200]	training's auc: 0.850343	training's binary_logloss: 0.445182	valid_1's auc: 0.579977	valid_1's binary_logloss: 0.510932
# OOF ROC 0.5793924423593231

# %%
cols = list(X_train.columns)
feature_imp = pd.DataFrame(sorted(zip(clf.feature_importances_,cols)), columns=['Value','Feature'])
plt.figure(figsize=(20, 10))
sns.barplot(x="Value", y="Feature", data=feature_imp.sort_values(by="Value", ascending=False).iloc[:20])
plt.title('LGBM Most Important Features')
#plt.tight_layout()
plt.show()

# %%
sub.failure = preds
sub
# Out:
#           id   failure
# 0      26570  0.203111
# 1      26571  0.194512
# 2      26572  0.196648
# 3      26573  0.196254
# 4      26574  0.248218
# ...      ...       ...
# 20770  47340  0.216678
# 20771  47341  0.173090
# 20772  47342  0.181780
# 20773  47343  0.204567
# 20774  47344  0.165110
#
# [20775 rows x 2 columns]

# %%
sub.to_csv('lgb_submission.csv', index = False)
